# %%
import pandas as pd
import matplotlib.pyplot as plt

import csv

world_ind = pd.read_csv('datasets/world_ind_pop_data.csv')
tweets = pd.read_csv('datasets/tweets.csv')

# %%
world_ind
# Out:
#                                    CountryName CountryCode  Year  \
# 0                                   Arab World         ARB  1960
# 1                       Caribbean small states         CSS  1960
# 2               Central Europe and the Baltics         CEB  1960
# 3      East Asia & Pacific (all income levels)         EAS  1960
# 4        East Asia & Pacific (developing only)         EAP  1960
# ...                                        ...         ...   ...
# 13369                    Virgin Islands (U.S.)         VIR  2014
# 13370                       West Bank and Gaza         WBG  2014
# 13371                              Yemen, Rep.         YEM  2014
# 13372                                   Zambia         ZMB  2014
# 13373                                 Zimbabwe         ZWE  2014
#
#        Total Population  Urban population (% of total)
# 0          9.249590e+07                      31.285384
# 1          4.190810e+06                      31.597490
# ...

# %%
tweets[['text']]
# Out:
#                                                  text
# 0   RT @bpolitics: .@krollbondrating's Christopher...
# 1   RT @HeidiAlpine: @dmartosko Cruz video found.....
# 2   Njihuni me Zonjën Trump !!! | Ekskluzive https...
# 3   Your an idiot she shouldn't have tried to grab...
# 4   RT @AlanLohner: The anti-American D.C. elites ...
# ..                                                ...
# 95  RT @claytoncubitt: Stop asking Bernie supporte...
# 96  Kasich is gonna fuck this up for Ted Cruz  htt...
# 97  RT @akaMaude13: Seriously can't make this up. ...
# 98  Kasich is gonna fuck this up for Ted Cruz  htt...
# 99  @marklevinshow try reporting this truth. https...
#
# [100 rows x 1 columns]

# %%
country_zip = zip(world_ind['CountryName'], world_ind['CountryCode'])
print(*country_zip)
# Out:
# ('Arab World', 'ARB') ('Caribbean small states', 'CSS') ('Central Europe and the Baltics', 'CEB') ('East Asia & Pacific (all income levels)', 'EAS') ('East Asia & Pacific (developing only)', 'EAP') ('Euro area', 'EMU') ('Europe & Central Asia (all income levels)', 'ECS') ('Europe & Central Asia (developing only)', 'ECA') ('European Union', 'EUU') ('Fragile and conflict affected situations', 'FCS') ('Heavily indebted poor countries (HIPC)', 'HPC') ('High income', 'HIC') ('High income: nonOECD', 'NOC') ('High income: OECD', 'OEC') ('Latin America & Caribbean (all income levels)', 'LCN') ('Latin America & Caribbean (developing only)', 'LAC') ('Least developed countries: UN classification', 'LDC') ('Low & middle income', 'LMY') ('Low income', 'LIC') ('Lower middle income', 'LMC') ('Middle East & North Africa (all income levels)', 'MEA') ('Middle East & North Africa (developing only)', 'MNA') ('Middle income', 'MIC') ('North America', 'NAC') ('OECD members', 'OED') ('Other small states', 
# ...

# %%
# first 25 characters of the `text` column of the `tweets` DataFrame provided that the tweet is not a retweet (i.e., starts with "RT").

texts = [txt for txt in tweets['text'] if not txt.startswith("RT")]
for i, x in enumerate(texts[:25], start=1): print(i, x)
# Out:
# 1 Njihuni me Zonjën Trump !!! | Ekskluzive https://t.co/4KmsQi47VD
# 2 Your an idiot she shouldn't have tried to grab trump after the fact she's an idiot https://t.co/lpASyeNVpG
# 3 Your an idiot she shouldn't have tried to grab trump after the fact she's an idiot https://t.co/lpASyeNVpG
# 4 #HillYes #ImWithHer #RollHillary @HillaryClinton  https://t.co/OwYXKIalyn
# 5 Trump won't do a yes ma'am for this.  https://t.co/r3WkGZDjPH
# 6 #HillYes #ImWithHer #RollHillary @HillaryClinton  https://t.co/OwYXKIalyn
# 7 Opinion: The big story is -- Sanders https://t.co/9Z9ZVnZ1Zi
# 8 GOP speechwriter: By November, Ivanka will be voting for Clinton | TheHill https://t.co/tUT7LpEHak
# 9 This dude must have some serious issues  https://t.co/ojYaDpnSoe
# 10 Opinion: The big story is -- Sanders https://t.co/9Z9ZVnZ1Zi
# 11 It Cometh from the Pit. And Hath a Knout https://t.co/iyF5HPDJNU
# #Trump
# #Election2016 https://t.co/W4ZXQfUHi8
# ...

# %%
# read `datasets/world_ind_pop_data.csv` in chunks of 20.

# %%
df_reader = pd.read_csv('datasets/world_ind_pop_data.csv',chunksize=20)
print(next(df_reader))
print(next(df_reader))
# Out:
#                                       CountryName CountryCode  Year  \
# 0                                      Arab World         ARB  1960
# 1                          Caribbean small states         CSS  1960
# 2                  Central Europe and the Baltics         CEB  1960
# 3         East Asia & Pacific (all income levels)         EAS  1960
# 4           East Asia & Pacific (developing only)         EAP  1960
# 5                                       Euro area         EMU  1960
# 6       Europe & Central Asia (all income levels)         ECS  1960
# 7         Europe & Central Asia (developing only)         ECA  1960
# 8                                  European Union         EUU  1960
# 9        Fragile and conflict affected situations         FCS  1960
# 10         Heavily indebted poor countries (HIPC)         HPC  1960
# 11                                    High income         HIC  1960
# 12                           High income: nonOECD         NOC  1960
# ...

# %%
df_reader = pd.read_csv('datasets/world_ind_pop_data.csv' , chunksize=20)
# Get the first DataFrame chunk: df_urb_pop
df_reader_pop = next(df_reader)
# Check out the head of the DataFrame
print(df_reader_pop.head())
# Out:
#                                CountryName CountryCode  Year  \
# 0                               Arab World         ARB  1960
# 1                   Caribbean small states         CSS  1960
# 2           Central Europe and the Baltics         CEB  1960
# 3  East Asia & Pacific (all income levels)         EAS  1960
# 4    East Asia & Pacific (developing only)         EAP  1960
#
#    Total Population  Urban population (% of total)
# 0      9.249590e+07                      31.285384
# 1      4.190810e+06                      31.597490
# 2      9.140158e+07                      44.507921
# 3      1.042475e+09                      22.471132
# 4      8.964930e+08                      16.917679
